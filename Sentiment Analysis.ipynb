# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/625.0 kB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 625.0/625.0 kB 2.8 MB/s  0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
data ={
    'Review':[
        'This product is amazing',
        'Very bad quality',
        'I love this phone',
        'The item is okay',
        'Worst purchase ever',
        'Excellent service and fast delivery',
        'Not satisfied with the product',
        'Pretty decent overall'
    ]
} 
df = pd.DataFrame(data)
df
# Out:
#                                 Review
# 0              This product is amazing
# 1                     Very bad quality
# 2                    I love this phone
# 3                     The item is okay
# 4                  Worst purchase ever
# 5  Excellent service and fast delivery
# 6       Not satisfied with the product
# 7                Pretty decent overall

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    
    if polarity > 0:
        return 'Positive'
    
    elif polarity < 0:
        return 'Negative'
    
    else:
        return 'Neutral'

df['Sentiment'] = df['Review'].apply(get_sentiment)

df
# Out:
#                                 Review Sentiment
# 0              This product is amazing  Positive
# 1                     Very bad quality  Negative
# 2                    I love this phone  Positive
# 3                     The item is okay  Positive
# 4                  Worst purchase ever  Negative
# 5  Excellent service and fast delivery  Positive
# 6       Not satisfied with the product  Negative
# 7                Pretty decent overall  Positive

# %%
sentiment_counts = df['Sentiment'].value_counts()
print(sentiment_counts)
# Out:
# Sentiment
# Positive    5
# Negative    3
# Name: count, dtype: int64

# %%
sentiment_counts.plot(kind='bar')
plt.title('Sentiment Analysis Results')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
print("""This project performs sentiment analysis using NLP techniques.
The reviews were classified into Positive, Negative, and Neutral sentiments using TextBlob.
Most reviews were positive, showing overall customer satisfaction.
Visualization helped understand sentiment distribution clearly.""")
# Out:
# This project performs sentiment analysis using NLP techniques.
# The reviews were classified into Positive, Negative, and Neutral sentiments using TextBlob.
# Most reviews were positive, showing overall customer satisfaction.
# Visualization helped understand sentiment distribution clearly.
